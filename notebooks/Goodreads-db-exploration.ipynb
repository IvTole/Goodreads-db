# %%
import pandas as pd
import numpy as np
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'src')))

import db_functions

# %%
fullpath = "../data/Goodreads_books_with_genres.csv"

#df_books = pd.read_json(fullpath, lines=True)
df_books = pd.read_csv(fullpath)

df_books.head(10)
# Out:
#    Book Id                                              Title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 1        2  Harry Potter and the Order of the Phoenix (Har...
# 2        4  Harry Potter and the Chamber of Secrets (Harry...
# 3        5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 5        9  Unauthorized Harry Potter Book Seven News: "Ha...
# 6       10       Harry Potter Collection (Harry Potter  #1-6)
# 7       12  The Ultimate Hitchhiker's Guide: Five Complete...
# 8       13  The Ultimate Hitchhiker's Guide to the Galaxy ...
# 9       14  The Hitchhiker's Guide to the Galaxy (Hitchhik...
#
#                        Author  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# ...

# %%
db_functions.connect()

for isbn in df_books['isbn']:
    book_id = db_functions.get_bookid_from_isbn(isbn)
    
    for authors_name in df_books[df_books['isbn']==isbn]['Author']:
        for author_name in authors_name.split(sep='/'):
            print(author_name)
            author_id = db_functions.get_authorid_from_authorname(author_name)
            print(book_id, author_id)
# Out:
# 1 1
# 1 2
# 2 1
# 2 2
# 4 1
# 5 1
# 5 2
# 8 1
# 8 2
# 9 3
# 10 1
# 12 4
# 13 4
# 14 4
# 16 4
# 16 5
# 18 4
# 21 6
# 22 6
# 23 6
# 24 6
# 25 6
# 26 6
# 27 6
# 28 6
# 29 6
# 30 7
# 31 7
# 34 7
# 35 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       6 for authors_name in df_books[df_books['isbn']==isbn]['Author']:
#       7     for author_name in authors_name.split(sep='/'):
# ----> 8         author_id = db_functions.get_authorid_from_authorname(author_name)
#       9         print(book_id, author_id)
#
# File ~/Documents/Doctorado/TSI/Github/Goodreads-db/src/db_functions.py:38, in get_authorid_from_authorname(author_name)
#      36     cursor.execute(query, (author_name,))
#      37     results = cursor.fetchone()
# ---> 38 return results['AuthorID']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df_books[df_books['Title']=='In Pursuit of the Proper Sinner (Inspector Lynley  #10)']
# Out:
#       Book Id                                              Title  \
# 8180    31373  In Pursuit of the Proper Sinner (Inspector Lyn...
#
#                  Author  average_rating        isbn         isbn13  \
# 8180  Elizabeth  George             4.1  0553575104  9780553575101
#
#      language_code  num_pages  ratings_count  text_reviews_count  \
# 8180           eng        718          10608                 295
#
#      publication_date     publisher  \
# 8180       11/31/2000  Bantam Books
#
#                                                  genres
# 8180  Mystery;Fiction;Mystery,Crime;Thriller,Mystery...

# %%
def list_flatten(list) -> list:
    return [x2 for x1 in list for x2 in x1]

series_genres = df_books['genres'].dropna() # column of interest
list_genres = series_genres.str.split(pat=";").values.tolist() # convert to list (separated)

#flat_list_genres = list_flatten(list_genres) # list flatten
#flat_list_genres_cap = [x.capitalize().strip() for x in flat_list_genres]
#array_genres_unique = pd.Series(flat_list_genres_cap).unique()

list_genres
# Out:
# [['Fantasy',
#   'Young Adult',
#   'Fiction',
#   'Fantasy,Magic',
#   'Childrens',
#   'Adventure',
#   'Audiobook',
#   'Childrens,Middle Grade',
#   'Classics',
#   'Science Fiction Fantasy'],
#  ['Fantasy',
#   'Young Adult',
#   'Fiction',
#   'Fantasy,Magic',
#   'Childrens',
#   'Adventure',
#   'Audiobook',
#   'Childrens,Middle Grade',
#   'Classics',
#   'Science Fiction Fantasy'],
#  ['Fantasy',
#   'Fiction',
#   'Young Adult',
#   'Fantasy,Magic',
#   'Childrens',
#   'Childrens,Middle Grade',
#   'Audiobook',
#   'Adventure',
#   'Classics',
#   'Science Fiction Fantasy'],
#  ['Fantasy',
#   'Fiction',
#   'Young Adult',
#   'Fantasy,Magic',
#   'Childrens',
#   'Childrens,Middle Grade',
#   'Adventure',
#   'Audiobook',
#   'Classics',
#   'Science Fiction Fantasy'],
#  ['Fantasy',
#   'Young Adult',
#   'Fiction',
#   'Fantasy,Magic',
#   'Adventure',
#   'Fantasy,Supernatural',
#   'Mystery',
#   'Childrens',
#   'Fantasy,Paranormal',
#   'Childrens,Middle Grade'],
# ...

# %%
df_books[df_books['Book Id']==9828]
# Out:
#       Book Id                                              Title  \
# 2674     9828  Rat Bastards: The Life and Times of South Bost...
#
#                              Author  average_rating        isbn  \
# 2674  John "Red" Shea/Mark Wahlberg            3.51  0060837160
#
#              isbn13 language_code  num_pages  ratings_count  \
# 2674  9780060837167           eng        304             34
#
#       text_reviews_count publication_date       publisher  \
# 2674                   3        3/14/2006  William Morrow
#
#                                      genres
# 2674  Crime,True Crime;Biography;Nonfiction

# %%
df_books.shape
# Out:
# (11127, 13)

# %%
series_authors = df_books['Author']

series_authors
# Out:
# 0                               J.K. Rowling/Mary GrandPré
# 1                               J.K. Rowling/Mary GrandPré
# 2                                             J.K. Rowling
# 3                               J.K. Rowling/Mary GrandPré
# 4                               J.K. Rowling/Mary GrandPré
#                                ...
# 11122    William T. Vollmann/Larry McCaffery/Michael He...
# 11123                                  William T. Vollmann
# 11124                                  William T. Vollmann
# 11125                                  William T. Vollmann
# 11126                                           Mark Twain
# Name: Author, Length: 11127, dtype: object

# %%
list_authors = series_authors.str.split(pat="/").values.tolist()

list_authors
# Out:
# [['J.K. Rowling', 'Mary GrandPré'],
#  ['J.K. Rowling', 'Mary GrandPré'],
#  ['J.K. Rowling'],
#  ['J.K. Rowling', 'Mary GrandPré'],
#  ['J.K. Rowling', 'Mary GrandPré'],
#  ['W. Frederick Zimmerman'],
#  ['J.K. Rowling'],
#  ['Douglas Adams'],
#  ['Douglas Adams'],
#  ['Douglas Adams'],
#  ['Douglas Adams', 'Stephen Fry'],
#  ['Douglas Adams'],
#  ['Bill Bryson'],
#  ['Bill Bryson'],
#  ['Bill Bryson'],
#  ['Bill Bryson'],
#  ['Bill Bryson'],
#  ['Bill Bryson'],
#  ['Bill Bryson'],
#  ['Bill Bryson'],
#  ['Bill Bryson'],
#  ['J.R.R. Tolkien'],
#  ['J.R.R. Tolkien'],
#  ['J.R.R. Tolkien'],
#  ['J.R.R. Tolkien', 'Alan  Lee'],
#  ['Chris   Smith', 'Christopher  Lee', 'Richard Taylor'],
#  ['Jude Fisher'],
#  ['Dave Thomas',
#   'David Heinemeier Hansson',
#   'Leon Breedt',
#   'Mike Clark',
#   'Thomas  Fuchs',
#   'Andreas  Schwarz'],
#  ['Gary Paulsen'],
#  ['Donna Ickes', 'Edward Sciranko', 'Keith Vasconcelles'],
#  ['Gary Paulsen'],
#  ['Molly Hatchet'],
#  ['Dale Peck'],
# ...

# %%
flat_list_authors = [x2 for x1 in list_authors for x2 in x1] # list comprehension

flat_list_authors
# Out:
# ['J.K. Rowling',
#  'Mary GrandPré',
#  'J.K. Rowling',
#  'Mary GrandPré',
#  'J.K. Rowling',
#  'J.K. Rowling',
#  'Mary GrandPré',
#  'J.K. Rowling',
#  'Mary GrandPré',
#  'W. Frederick Zimmerman',
#  'J.K. Rowling',
#  'Douglas Adams',
#  'Douglas Adams',
#  'Douglas Adams',
#  'Douglas Adams',
#  'Stephen Fry',
#  'Douglas Adams',
#  'Bill Bryson',
#  'Bill Bryson',
#  'Bill Bryson',
#  'Bill Bryson',
#  'Bill Bryson',
#  'Bill Bryson',
#  'Bill Bryson',
#  'Bill Bryson',
#  'Bill Bryson',
#  'J.R.R. Tolkien',
#  'J.R.R. Tolkien',
#  'J.R.R. Tolkien',
#  'J.R.R. Tolkien',
#  'Alan  Lee',
#  'Chris   Smith',
#  'Christopher  Lee',
#  'Richard Taylor',
#  'Jude Fisher',
#  'Dave Thomas',
#  'David Heinemeier Hansson',
#  'Leon Breedt',
#  'Mike Clark',
#  'Thomas  Fuchs',
#  'Andreas  Schwarz',
#  'Gary Paulsen',
#  'Donna Ickes',
#  'Edward Sciranko',
#  'Keith Vasconcelles',
#  'Gary Paulsen',
#  'Molly Hatchet',
#  'Dale Peck',
#  'Angela Knight',
#  'Sahara Kelly',
# ...

# %%
pd.Series(flat_list_authors).unique()
# Out:
# array(['J.K. Rowling', 'Mary GrandPré', 'W. Frederick Zimmerman', ...,
#        'Ana Falcão Bastos', 'Larry McCaffery', 'Michael Hemmingson'],
#       dtype=object)

# %%
series_authors.explode()
# Out:
# 0                               J.K. Rowling/Mary GrandPré
# 1                               J.K. Rowling/Mary GrandPré
# 2                                             J.K. Rowling
# 3                               J.K. Rowling/Mary GrandPré
# 4                               J.K. Rowling/Mary GrandPré
#                                ...
# 11122    William T. Vollmann/Larry McCaffery/Michael He...
# 11123                                  William T. Vollmann
# 11124                                  William T. Vollmann
# 11125                                  William T. Vollmann
# 11126                                           Mark Twain
# Name: Author, Length: 11127, dtype: object

# %%
pd.Series(flat_list_authors).unique()[8]
# Out:
# 'Chris   Smith'

# %%
df_books[df_books['Author'] == 'Chris Smith']
# Out:
# Empty DataFrame
# Columns: [Book Id, Title, Author, average_rating, isbn, isbn13, language_code, num_pages, ratings_count, text_reviews_count, publication_date, publisher, genres]
# Index: []

# %%
test_string = pd.Series(flat_list_authors).unique()[8]
test_string
# Out:
# 'Chris   Smith'

# %%
" ".join(test_string.split())
# Out:
# 'Chris Smith'

# %% [markdown]
# Table name: books
# * BookID (PK)
# * Title
# * ISBN
# * ISBN13
# * Language
# * PublicationYear
# * Publisher
# * NumPages

# %%
df_books['isbn'].unique().shape
# Out:
# (11127,)

# %%
df_books.shape
# Out:
# (11127, 13)

# %%
df_books['isbn13'].unique().shape
# Out:
# (11127,)

# %%
series_title = df_books['Title']
series_title.unique().shape
# Out:
# (10352,)

# %%
duplicates = df_books[df_books['Title'].duplicated(keep=False)]

# %%
duplicates.shape
# Out:
# (1262, 13)

# %%
duplicates
# Out:
#        Book Id                                              Title  \
# 0            1  Harry Potter and the Half-Blood Prince (Harry ...
# 2            4  Harry Potter and the Chamber of Secrets (Harry...
# 3            5  Harry Potter and the Prisoner of Azkaban (Harr...
# 9           14  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 10          16  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# ...        ...                                                ...
# 11079    45463          Encuentro en el Ártico (Artemis Fowl  #2)
# 11080    45465                    Artemis Fowl (Artemis Fowl  #1)
# 11082    45479          The Subtle Knife (His Dark Materials  #2)
# 11084    45485          The Subtle Knife (His Dark Materials  #2)
# 11100    45536                                        On the Road
#
#                               Author  average_rating        isbn  \
# 0         J.K. Rowling/Mary GrandPré            4.57  0439785960
# ...

# %%
df_books[df_books['Title'] == "On the Road"]
# Out:
#        Book Id        Title                     Author  average_rating  \
# 783       2551  On the Road               Jack Kerouac            3.63
# 784       2552  On the Road  Jack Kerouac/Ann Charters            3.63
# 11100    45536  On the Road  Jack Kerouac/Ann Charters            3.63
#
#              isbn         isbn13 language_code  num_pages  ratings_count  \
# 783    0143036386  9780143036388           eng        320            488
# 784    0141182679  9780141182674           eng        281           5575
# 11100  0142437255  9780142437254         en-US        307           3271
#
#        text_reviews_count publication_date         publisher  \
# 783                    39         9/6/2005     Penguin Books
# 784                   502        2/24/2000     Penguin Books
# 11100                 342         1/3/2006  Penguin Classics
#
#                                                   genres
# 783    Classics;Fiction;Travel;Literature;Novels;Lite...
# ...

# %%
df_books.columns
# Out:
# Index(['Book Id', 'Title', 'Author', 'average_rating', 'isbn', 'isbn13',
#        'language_code', 'num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher', 'genres'],
#       dtype='object')

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Book Id             11127 non-null  int64
#  1   Title               11127 non-null  object
#  2   Author              11127 non-null  object
#  3   average_rating      11127 non-null  float64
#  4   isbn                11127 non-null  object
#  5   isbn13              11127 non-null  int64
#  6   language_code       11127 non-null  object
#  7   num_pages           11127 non-null  int64
#  8   ratings_count       11127 non-null  int64
#  9   text_reviews_count  11127 non-null  int64
#  10  publication_date    11127 non-null  object
#  11  publisher           11127 non-null  object
#  12  genres              11030 non-null  object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 1.1+ MB

# %%
df_books['publication_date'] = pd.to_datetime(df_books['publication_date'], format='%m/%d/%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df_books['publication_date'] = pd.to_datetime(df_books['publication_date'], format='%m/%d/%Y')
#
# File ~/anaconda3/envs/tsi_ml_env/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/anaconda3/envs/tsi_ml_env/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
df_books.iloc[8180]['publication_date'] = '11/30/2000'
# Out:
# /var/folders/ls/3cpc9bjx04xfmf_tzhgzfgrm0000gn/T/ipykernel_16220/3381746998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books.iloc[8180]['publication_date'] = '11/30/2000'

# %%
df_books.iloc[11098]
# Out:
# Book Id                                                           45531
# Title                        Montaillou  village occitan de 1294 à 1324
# Author                  Emmanuel Le Roy Ladurie/Emmanuel Le Roy-Ladurie
# average_rating                                                     3.96
# isbn                                                         2070323285
# isbn13                                                    9782070323289
# language_code                                                       fre
# num_pages                                                           640
# ratings_count                                                        15
# text_reviews_count                                                    2
# publication_date                                              6/31/1982
# publisher                                                Folio histoire
# genres                History;Nonfiction;Cultural,France;Historical,...
# Name: 11098, dtype: object

# %% [markdown]
# ## Dataframe grande (ratings y reviews)

# %%
df_reviews = pd.read_csv("../data/goodreads_train.csv")
df_reviews.head()
# Out:
#                             user_id   book_id  \
# 0  8842281e1d1347389f2ab93d60773d4d  18245960
# 1  8842281e1d1347389f2ab93d60773d4d     16981
# 2  8842281e1d1347389f2ab93d60773d4d  28684704
# 3  8842281e1d1347389f2ab93d60773d4d  27161156
# 4  8842281e1d1347389f2ab93d60773d4d  25884323
#
#                           review_id  rating  \
# 0  dfdbb7b0eb5a7e4c26d59a937e2e5feb       5
# 1  a5d2c3628987712d0e05c4f90798eb67       3
# 2  2ede853b14dc4583f96cf5d120af636f       3
# 3  ced5675e55cd9d38a524743f5c40996e       0
# 4  332732725863131279a8e345b63ac33e       4
#
#                                          review_text  \
# 0  This is a special book. It started slow for ab...
# 1  Recommended by Don Katz. Avail for free in Dec...
# 2  A fun, fast paced science fiction thriller. I ...
# 3  Recommended reading to understand what is goin...
# 4  I really enjoyed this book, and there is a lot...
#
#                        date_added                    date_updated  \
# ...

# %%
df_reviews[df_reviews["book_id"] < 11000].shape
# Out:
# (32718, 11)

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900000 entries, 0 to 899999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       900000 non-null  object
#  1   book_id       900000 non-null  int64
#  2   review_id     900000 non-null  object
#  3   rating        900000 non-null  int64
#  4   review_text   900000 non-null  object
#  5   date_added    900000 non-null  object
#  6   date_updated  900000 non-null  object
#  7   read_at       808234 non-null  object
#  8   started_at    625703 non-null  object
#  9   n_votes       900000 non-null  int64
#  10  n_comments    900000 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 75.5+ MB
